# %% [markdown]
# <a href="https://colab.research.google.com/github/shwetakkk21/apslab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
# user input graph using dictionary
print("Enter the number of nodes in the graph:")
num_nodes = int(input())
for i in range(num_nodes):
  node=input("Enter the name of node:")
  graph[node]={}
  num_edges=int(input("Enter the number of edges connected to this node:"))
  for j in range(num_edges):
    neighbor=input("Enter the name of neighbor node:")
    weight=int(input("Enter the weight of the edge between these two nodes:"))
    graph[node][neighbor]=weight
source=input("Enter the source node:")
result = dijkstra(graph, source)
for node in result:
  print("Distance from",source,"to", node, "=", result[node])
# Out:
# Enter the number of nodes in the graph:
# 4
# Enter the name of node:A
# Enter the number of edges connected to this node:2
# Enter the name of neighbor node:B
# Enter the weight of the edge between these two nodes:4
# Enter the name of neighbor node:C
# Enter the weight of the edge between these two nodes:2
# Enter the name of node:B
# Enter the number of edges connected to this node:3
# Enter the name of neighbor node:A
# Enter the weight of the edge between these two nodes:4
# Enter the name of neighbor node:C
# Enter the weight of the edge between these two nodes:5
# Enter the name of neighbor node:D
# Enter the weight of the edge between these two nodes:10
# Enter the name of node:C
# Enter the number of edges connected to this node:3
# Enter the name of neighbor node:A
# Enter the weight of the edge between these two nodes:2
# Enter the name of neighbor node:B
# Enter the weight of the edge between these two nodes:5
# Enter the name of neighbor node:D
# Enter the weight of the edge between these two nodes:3
# Enter the name of node:D
# Enter the number of edges connected to this node:2
# Enter the name of neighbor node:B
# Enter the weight of the edge between these two nodes:10
# Enter the name of neighbor node:C
# Enter the weight of the edge between these two nodes:3
# Enter the source node:A
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %%
# display shortest path with total distance
def dijkstra_path(graph, start,end):

    distances = {}
    visited = []
    tree={}
    tree[start]=None

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                tree[neighbor]=min_node

    path=[]
    node=end
    while node!=None:
        path.append(node)
        node=tree[node]

    return path,distances[end]

path,distance=dijkstra_path(graph, 'A','D')
print("Shortest path:")
for i in range(len(path)-1,-1,-1):
  print(path[i],end="")
  if i!=0:
    print("->",end="")
print("\nTotal distance:",distance)
# Out:
# Shortest path:
# A->C->D
# Total distance: 5

# %%
# add two more nodes in graph
graph['E']={}
graph['F']={}
graph['E']['F']=7
graph['F']['E']=7
graph['E']['D']=1
graph['D']['E']=1
graph['F']['D']=3
graph['D']['F']=3

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])

path,distance=dijkstra_path(graph, 'A','F')
print("Shortest path:")
for i in range(len(path)-1,-1,-1):
  print(path[i],end="")
  if i!=0:
    print("->",end="")
print("\nTotal distance:",distance)
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
# Distance from A to E = 6
# Distance from A to F = 8
# Shortest path:
# A->C->D->F
# Total distance: 8

# %%
# test from different nodes
start='B'
result = dijkstra(graph,start)

for node in result:
    print("Distance from", start, "to", node, "=", result[node])

path,distance=dijkstra_path(graph, start,'F')
print("Shortest path:")
for i in range(len(path)-1,-1,-1):
  print(path[i],end="")
  if i!=0:
    print("->",end="")
print("\nTotal distance:",distance)
# Out:
# Distance from B to A = 4
# Distance from B to B = 0
# Distance from B to C = 5
# Distance from B to D = 8
# Distance from B to E = 9
# Distance from B to F = 11
# Shortest path:
# B->C->D->F
# Total distance: 11
